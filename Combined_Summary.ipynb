# %%
import pandas as pd
import numpy as np

# %%
combined_file = 'Group 6 Data(2).csv'

combined_df = pd.read_csv(combined_file)
combined_df.head()
# Out:
#    US News Ranking                     Hospital Name Billing Code Type  \
# 0                8  NYU Langone Hospitals Hospital A             MSDRG
# 1                8  NYU Langone Hospitals Hospital A             MSDRG
# 2                8  NYU Langone Hospitals Hospital A             MSDRG
# 3                8  NYU Langone Hospitals Hospital A             MSDRG
# 4                8  NYU Langone Hospitals Hospital A             MSDRG
#
#    DRG Number                                    DRG Description  Payor  \
# 0           1  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  Aetna
# 1           2  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  Aetna
# 2           3  ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  Aetna
# 3           4  TRACHEOSTOMY WITH MV >96 HOURS OR PRINCIPAL DI...  Aetna
# 4           5  LIVER TRANSPLANT WITH MCC OR INTESTINAL TRANSP...  Aetna
#
#                       Plan  Charge Amount
# 0  Hospital A1005AETNA HMO       618308.8
# ...

# %%
combined_df['Charge Amount'].dtypes
# Out:
# dtype('float64')

# %%
combined_df["Charge Amount"] = pd.to_numeric(combined_df["Charge Amount"])

# %%
combined_df.describe()
# Out:
#        US News Ranking    DRG Number  Charge Amount
# count     1.201863e+06  1.201863e+06   1.201863e+06
# mean      8.640340e+00  4.773627e+02   5.331706e+04
# std       2.888798e+00  2.801826e+02   9.226388e+04
# min       1.000000e+00  1.000000e+00   9.820000e+00
# 25%       8.000000e+00  2.410000e+02   1.548339e+04
# 50%       8.000000e+00  4.720000e+02   2.956684e+04
# 75%       8.000000e+00  7.180000e+02   5.809670e+04
# max       2.000000e+01  9.990000e+02   3.649520e+07

# %%
print(combined_df.groupby('Payor').describe())
# Out:
#                   US News Ranking                                            \
#                             count       mean       std  min  25%  50%   75%
# Payor
# Aetna                     64541.0  10.806573  4.925317  2.0  8.0  8.0  14.0
# BCBS                     196794.0   8.793800  2.801633  1.0  8.0  8.0   8.0
# Cigna                     63862.0   9.627697  4.162618  2.0  8.0  8.0  10.0
# Gross Charge               4309.0   9.241123  5.500749  2.0  5.0  7.0  14.0
# Other                    789450.0   8.289371  2.221213  1.0  8.0  8.0   8.0
# Self Pay                   5027.0   8.206883  5.688261  2.0  2.0  7.0  14.0
# United Healthcare         77880.0   9.200141  3.810863  2.0  8.0  8.0   8.0
#
#                         DRG Number              ...                \
#                     max      count        mean  ...    75%    max
# Payor                                           ...
# Aetna              20.0    64541.0  477.715514  ...  722.0  999.0
# ...

# %%
print(combined_df.groupby('DRG Number').describe())
# Out:
#            US News Ranking                                                 \
#                      count      mean       std  min  25%  50%   75%   max
# DRG Number
# 1                   1645.0  8.582979  3.175898  1.0  8.0  8.0   8.0  20.0
# 2                   1514.0  8.670410  2.623113  1.0  8.0  8.0   8.0  20.0
# 3                   1691.0  8.646363  3.235027  1.0  8.0  8.0   8.0  20.0
# 4                   1668.0  8.589928  3.148162  1.0  8.0  8.0   8.0  20.0
# 5                   1546.0  8.451488  2.867614  1.0  8.0  8.0   8.0  20.0
# ...                    ...       ...       ...  ...  ...  ...   ...   ...
# 987                 1636.0  8.654645  3.003960  1.0  8.0  8.0   8.0  20.0
# 988                 1629.0  8.615101  2.951457  1.0  8.0  8.0   8.0  20.0
# 989                 1594.0  8.697616  2.850783  1.0  8.0  8.0   8.0  20.0
# 998                  269.0  9.211896  2.513339  3.0  8.0  8.0  10.0  14.0
# ...

# %%
combined_df.describe()
# Out:
#        US News Ranking    DRG Number  Charge Amount
# count     1.201863e+06  1.201863e+06   1.201863e+06
# mean      8.640340e+00  4.773627e+02   5.331706e+04
# std       2.888798e+00  2.801826e+02   9.226388e+04
# min       1.000000e+00  1.000000e+00   9.820000e+00
# 25%       8.000000e+00  2.410000e+02   1.548339e+04
# 50%       8.000000e+00  4.720000e+02   2.956684e+04
# 75%       8.000000e+00  7.180000e+02   5.809670e+04
# max       2.000000e+01  9.990000e+02   3.649520e+07

# %%
combined_df.count(axis=0)
# Out:
# US News Ranking      1201863
# Hospital Name        1201863
# Billing Code Type    1201863
# DRG Number           1201863
# DRG Description      1201777
# Payor                1201863
# Plan                 1201863
# Charge Amount        1201863
# dtype: int64

# %%
combined_df['Charge Amount'].isna().sum()
# Out:
# 0

# %%
combined_df.isna()
# Out:
#          US News Ranking  Hospital Name  Billing Code Type  DRG Number  \
# 0                  False          False              False       False
# 1                  False          False              False       False
# 2                  False          False              False       False
# 3                  False          False              False       False
# 4                  False          False              False       False
# ...                  ...            ...                ...         ...
# 1201858            False          False              False       False
# 1201859            False          False              False       False
# 1201860            False          False              False       False
# 1201861            False          False              False       False
# 1201862            False          False              False       False
#
#          DRG Description  Payor   Plan  Charge Amount
# 0                  False  False  False          False
# ...

# %%
combined_df.drop("DRG Description", axis=1, inplace=True)

# %%
combined_df
# Out:
#          US News Ranking                     Hospital Name Billing Code Type  \
# 0                      8  NYU Langone Hospitals Hospital A             MSDRG
# 1                      8  NYU Langone Hospitals Hospital A             MSDRG
# 2                      8  NYU Langone Hospitals Hospital A             MSDRG
# 3                      8  NYU Langone Hospitals Hospital A             MSDRG
# 4                      8  NYU Langone Hospitals Hospital A             MSDRG
# ...                  ...                               ...               ...
# 1201858               17            Barnes-Jewish Hospital               DRG
# 1201859               17            Barnes-Jewish Hospital               DRG
# 1201860               17            Barnes-Jewish Hospital               DRG
# 1201861               17            Barnes-Jewish Hospital               DRG
# 1201862               17            Barnes-Jewish Hospital               DRG
#
# ...

# %%
combined_df.drop("Billing Code Type", axis=1, inplace=True)

# %%
combined_df
# Out:
#          US News Ranking                     Hospital Name  DRG Number  \
# 0                      8  NYU Langone Hospitals Hospital A           1
# 1                      8  NYU Langone Hospitals Hospital A           2
# 2                      8  NYU Langone Hospitals Hospital A           3
# 3                      8  NYU Langone Hospitals Hospital A           4
# 4                      8  NYU Langone Hospitals Hospital A           5
# ...                  ...                               ...         ...
# 1201858               17            Barnes-Jewish Hospital         982
# 1201859               17            Barnes-Jewish Hospital         982
# 1201860               17            Barnes-Jewish Hospital         982
# 1201861               17            Barnes-Jewish Hospital         983
# 1201862               17            Barnes-Jewish Hospital         987
#
#                      Payor                     Plan  Charge Amount
# ...

# %%
DRG_Name = 'DRG_description.csv'
drg_name_df = pd.read_csv(DRG_Name)
drg_name_df.head()
# Out:
#    DRG Number                                    DRG Description  \
# 0           1  Heart transplant or implant of heart assist sy...
# 1           2  Heart transplant or implant of heart assist sy...
# 2           3  ECMO or tracheostomy with MV > hours or PDX ex...
# 3           4  Tracheostomy with MV > hours or PDX except fac...
# 4           5  Liver transplant with MCC or intestinal transp...
#
#                                           Unnamed: 2
# 0  ���Heart transplant or implant of heart assist...
# 1  ���Heart transplant or implant of heart assist...
# 2  ���ECMO or tracheostomy with MV > hours or PDX...
# 3  ���Tracheostomy with MV > hours or PDX except ...
# 4  ���Liver transplant with MCC or intestinal tra...

# %%
drg_df=pd.merge(combined_df,drg_name_df, how='left', on='DRG Number', sort=True)

# %%
drg_df.head()
# Out:
#    US News Ranking                     Hospital Name  DRG Number  Payor  \
# 0                8  NYU Langone Hospitals Hospital A           1  Aetna
# 1                8  NYU Langone Hospitals Hospital B           1  Aetna
# 2                8  NYU Langone Hospitals Hospital C           1  Aetna
# 3                8  NYU Langone Hospitals Hospital D           1  Aetna
# 4                8  NYU Langone Hospitals Hospital A           1  Aetna
#
#                             Plan  Charge Amount  \
# 0        Hospital A1005AETNA HMO       618308.8
# 1        Hospital B1005AETNA HMO       618308.8
# 2        Hospital C1005AETNA HMO       475737.8
# 3        Hospital D1005AETNA HMO       576211.2
# 4  Hospital A1006AETNA INDEMNITY      1981340.0
#
#                                      DRG Description  \
# 0  Heart transplant or implant of heart assist sy...
# 1  Heart transplant or implant of heart assist sy...
# 2  Heart transplant or implant of heart assist sy...
# ...

# %%
drg_df.drop("Unnamed: 2", axis=1, inplace=True)

# %%
drg_df.head()
# Out:
#    US News Ranking                     Hospital Name  DRG Number  Payor  \
# 0                8  NYU Langone Hospitals Hospital A           1  Aetna
# 1                8  NYU Langone Hospitals Hospital B           1  Aetna
# 2                8  NYU Langone Hospitals Hospital C           1  Aetna
# 3                8  NYU Langone Hospitals Hospital D           1  Aetna
# 4                8  NYU Langone Hospitals Hospital A           1  Aetna
#
#                             Plan  Charge Amount  \
# 0        Hospital A1005AETNA HMO       618308.8
# 1        Hospital B1005AETNA HMO       618308.8
# 2        Hospital C1005AETNA HMO       475737.8
# 3        Hospital D1005AETNA HMO       576211.2
# 4  Hospital A1006AETNA INDEMNITY      1981340.0
#
#                                      DRG Description
# 0  Heart transplant or implant of heart assist sy...
# 1  Heart transplant or implant of heart assist sy...
# 2  Heart transplant or implant of heart assist sy...
# ...

# %%
drg_df
# Out:
#          US News Ranking                     Hospital Name  DRG Number  \
# 0                      8  NYU Langone Hospitals Hospital A           1
# 1                      8  NYU Langone Hospitals Hospital B           1
# 2                      8  NYU Langone Hospitals Hospital C           1
# 3                      8  NYU Langone Hospitals Hospital D           1
# 4                      8  NYU Langone Hospitals Hospital A           1
# ...                  ...                               ...         ...
# 1201858                2                  Cleveland Clinic         999
# 1201859                2                  Cleveland Clinic         999
# 1201860                2                  Cleveland Clinic         999
# 1201861                2                  Cleveland Clinic         999
# 1201862                3               UCLA Medical Center         999
#
#                      Payor                           Plan  Charge Amount  \
# ...

# %%
drg_df=drg_df.drop_duplicates()

# %%
drg_df.to_csv("Group6_DRG.csv")
