# %%
import pandas as pd
import numpy as np
import json
import os
import ast

# %%
filepath=os.path.join("UCLA_MRF.json")
with open(filepath) as jsonfile:
    data_json =pd.read_json(jsonfile)

# %%
data_json
# Out:
#                        Ronald Reagan UCLA Medical Center           field2  \
# 0      Prices Posted 4/1/2021\nPrices Effective 7/1/2020
# 1                                            Description      Code \nType
# 2      Heart transplant or implant of heart assist sy...              DRG
# 3      Heart transplant or implant of heart assist sy...              DRG
# 4      ECMO or trach w MV >96 hrs or PDX exc face, mo...              DRG
# ...                                                  ...              ...
# 52332                                         SM, RR, NP  Pharmaceuticals
# 52333                                         SM, RR, NP  Pharmaceuticals
# 52334                                         SM, RR, NP  Pharmaceuticals
# 52335                                         SM, RR, NP  Pharmaceuticals
# 52336                                         SM, RR, NP  Pharmaceuticals
#
#                         field3             field4 field5         field6  \
# 0
# 1         CPT/HCPCS \nDRG Code  Code\nCDM/ERX/SUP    NDC  Revenue\nCode
# 2      MS-DRG V37 (FY2020) 001                        NA
# 3      MS-DRG V37 (FY2020) 002                        NA
# 4      MS-DRG V37 (FY2020) 003                        NA
# ...                        ...                ...    ...            ...
# 52332                                50242-063-01  C9399     2500003636
# 52333                                0944-8702-02  C9399     2500003636
# 52334                                0338-4212-10  C9399     2500003636
# 52335                                0338-4210-02  C9399     2500003636
# 52336                                0338-4211-04  C9399     2500003636
#
#                               field7       field8        field9  \
# 0
# 1                           Quantity  IP XR Aetna  IP XR Anthem
# 2                                        Variable      Variable
# 3                                        Variable      Variable
# 4                                        Variable      Variable
# ...                              ...          ...           ...
# 52332   ERLOTINIB HCL 100 MG PO TABS        788.4
# 52333  TACHOSIL 4.8 X 4.8 CM EX PTCH       1571.2
# 52334        TISSEEL VH 10 ML EX KIT      2349.32
# 52335         TISSEEL VH 2 ML EX KIT      494.225
# 52336         TISSEEL VH 4 ML EX KIT        839.3
#
#                   field10       field11            field12        field13  \
# 0
# 1      IP XR\nBlue Shield  IP XR\nCigna  IP XR\nHealth Net  IP XR\nKaiser
# 2                Variable      Variable           Variable       Variable
# 3                Variable      Variable           Variable       Variable
# 4                Variable      Variable           Variable       Variable
# ...                   ...           ...                ...            ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
#               field14   field15   field16
# 0
# 1       IP XR\nUnited       Min       Max
# 2      1129072.495194  Variable  Variable
# 3       545434.368297  Variable  Variable
# 4       709253.482476  Variable  Variable
# ...               ...       ...       ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# [52337 rows x 16 columns]

# %%
data_json.drop(data_json.index[[0]])
# Out:
#                        Ronald Reagan UCLA Medical Center           field2  \
# 1                                            Description      Code \nType
# 2      Heart transplant or implant of heart assist sy...              DRG
# 3      Heart transplant or implant of heart assist sy...              DRG
# 4      ECMO or trach w MV >96 hrs or PDX exc face, mo...              DRG
# 5      Trach w MV >96 hrs or PDX exc face, mouth & ne...              DRG
# ...                                                  ...              ...
# 52332                                         SM, RR, NP  Pharmaceuticals
# 52333                                         SM, RR, NP  Pharmaceuticals
# 52334                                         SM, RR, NP  Pharmaceuticals
# 52335                                         SM, RR, NP  Pharmaceuticals
# 52336                                         SM, RR, NP  Pharmaceuticals
#
#                         field3             field4 field5         field6  \
# 1         CPT/HCPCS \nDRG Code  Code\nCDM/ERX/SUP    NDC  Revenue\nCode
# 2      MS-DRG V37 (FY2020) 001                        NA
# 3      MS-DRG V37 (FY2020) 002                        NA
# 4      MS-DRG V37 (FY2020) 003                        NA
# 5      MS-DRG V37 (FY2020) 004                        NA
# ...                        ...                ...    ...            ...
# 52332                                50242-063-01  C9399     2500003636
# 52333                                0944-8702-02  C9399     2500003636
# 52334                                0338-4212-10  C9399     2500003636
# 52335                                0338-4210-02  C9399     2500003636
# 52336                                0338-4211-04  C9399     2500003636
#
#                               field7       field8        field9  \
# 1                           Quantity  IP XR Aetna  IP XR Anthem
# 2                                        Variable      Variable
# 3                                        Variable      Variable
# 4                                        Variable      Variable
# 5                                        Variable      Variable
# ...                              ...          ...           ...
# 52332   ERLOTINIB HCL 100 MG PO TABS        788.4
# 52333  TACHOSIL 4.8 X 4.8 CM EX PTCH       1571.2
# 52334        TISSEEL VH 10 ML EX KIT      2349.32
# 52335         TISSEEL VH 2 ML EX KIT      494.225
# 52336         TISSEEL VH 4 ML EX KIT        839.3
#
#                   field10       field11            field12        field13  \
# 1      IP XR\nBlue Shield  IP XR\nCigna  IP XR\nHealth Net  IP XR\nKaiser
# 2                Variable      Variable           Variable       Variable
# 3                Variable      Variable           Variable       Variable
# 4                Variable      Variable           Variable       Variable
# 5                Variable      Variable           Variable       Variable
# ...                   ...           ...                ...            ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
#               field14   field15   field16
# 1       IP XR\nUnited       Min       Max
# 2      1129072.495194  Variable  Variable
# 3       545434.368297  Variable  Variable
# 4       709253.482476  Variable  Variable
# 5        439008.36654  Variable  Variable
# ...               ...       ...       ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# [52336 rows x 16 columns]

# %%
# data_json =data_json.columns(['Description'], ['Code'],['CPT/HCPCS'], ['Code_Type'], ['NDC'], ['Revenue Code'],['Quanity'], ['IP XR Aetna'], ['IP XR Anthem'], ['IP XR BCBS'], ['IP XR Cigna'], ['IP XR Health Net'], ['IP XR Kaiser'], ['IP XR United'], ['Min'], ['Max'])

# %%
data_json.columns=data_json.iloc[1]

# %%
data_json
# Out:
# 1                                            Description      Code \nType  \
# 0      Prices Posted 4/1/2021\nPrices Effective 7/1/2020
# 1                                            Description      Code \nType
# 2      Heart transplant or implant of heart assist sy...              DRG
# 3      Heart transplant or implant of heart assist sy...              DRG
# 4      ECMO or trach w MV >96 hrs or PDX exc face, mo...              DRG
# ...                                                  ...              ...
# 52332                                         SM, RR, NP  Pharmaceuticals
# 52333                                         SM, RR, NP  Pharmaceuticals
# 52334                                         SM, RR, NP  Pharmaceuticals
# 52335                                         SM, RR, NP  Pharmaceuticals
# 52336                                         SM, RR, NP  Pharmaceuticals
#
# 1         CPT/HCPCS \nDRG Code  Code\nCDM/ERX/SUP    NDC  Revenue\nCode  \
# 0
# 1         CPT/HCPCS \nDRG Code  Code\nCDM/ERX/SUP    NDC  Revenue\nCode
# 2      MS-DRG V37 (FY2020) 001                        NA
# 3      MS-DRG V37 (FY2020) 002                        NA
# 4      MS-DRG V37 (FY2020) 003                        NA
# ...                        ...                ...    ...            ...
# 52332                                50242-063-01  C9399     2500003636
# 52333                                0944-8702-02  C9399     2500003636
# 52334                                0338-4212-10  C9399     2500003636
# 52335                                0338-4210-02  C9399     2500003636
# 52336                                0338-4211-04  C9399     2500003636
#
# 1                           Quantity  IP XR Aetna  IP XR Anthem  \
# 0
# 1                           Quantity  IP XR Aetna  IP XR Anthem
# 2                                        Variable      Variable
# 3                                        Variable      Variable
# 4                                        Variable      Variable
# ...                              ...          ...           ...
# 52332   ERLOTINIB HCL 100 MG PO TABS        788.4
# 52333  TACHOSIL 4.8 X 4.8 CM EX PTCH       1571.2
# 52334        TISSEEL VH 10 ML EX KIT      2349.32
# 52335         TISSEEL VH 2 ML EX KIT      494.225
# 52336         TISSEEL VH 4 ML EX KIT        839.3
#
# 1      IP XR\nBlue Shield  IP XR\nCigna  IP XR\nHealth Net  IP XR\nKaiser  \
# 0
# 1      IP XR\nBlue Shield  IP XR\nCigna  IP XR\nHealth Net  IP XR\nKaiser
# 2                Variable      Variable           Variable       Variable
# 3                Variable      Variable           Variable       Variable
# 4                Variable      Variable           Variable       Variable
# ...                   ...           ...                ...            ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# 1       IP XR\nUnited       Min       Max
# 0
# 1       IP XR\nUnited       Min       Max
# 2      1129072.495194  Variable  Variable
# 3       545434.368297  Variable  Variable
# 4       709253.482476  Variable  Variable
# ...               ...       ...       ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# [52337 rows x 16 columns]

# %%
new_ucla=data_json.drop(data_json.index[[0,1]])

# %%
new_ucla
# Out:
# 1                                            Description      Code \nType  \
# 2      Heart transplant or implant of heart assist sy...              DRG
# 3      Heart transplant or implant of heart assist sy...              DRG
# 4      ECMO or trach w MV >96 hrs or PDX exc face, mo...              DRG
# 5      Trach w MV >96 hrs or PDX exc face, mouth & ne...              DRG
# 6                                       Liver transplant              DRG
# ...                                                  ...              ...
# 52332                                         SM, RR, NP  Pharmaceuticals
# 52333                                         SM, RR, NP  Pharmaceuticals
# 52334                                         SM, RR, NP  Pharmaceuticals
# 52335                                         SM, RR, NP  Pharmaceuticals
# 52336                                         SM, RR, NP  Pharmaceuticals
#
# 1         CPT/HCPCS \nDRG Code Code\nCDM/ERX/SUP    NDC Revenue\nCode  \
# 2      MS-DRG V37 (FY2020) 001                       NA
# 3      MS-DRG V37 (FY2020) 002                       NA
# 4      MS-DRG V37 (FY2020) 003                       NA
# 5      MS-DRG V37 (FY2020) 004                       NA
# 6      MS-DRG V37 (FY2020) 005                       NA
# ...                        ...               ...    ...           ...
# 52332                               50242-063-01  C9399    2500003636
# 52333                               0944-8702-02  C9399    2500003636
# 52334                               0338-4212-10  C9399    2500003636
# 52335                               0338-4210-02  C9399    2500003636
# 52336                               0338-4211-04  C9399    2500003636
#
# 1                           Quantity IP XR Aetna IP XR Anthem  \
# 2                                       Variable     Variable
# 3                                       Variable     Variable
# 4                                       Variable     Variable
# 5                                       Variable     Variable
# 6                                       Variable     Variable
# ...                              ...         ...          ...
# 52332   ERLOTINIB HCL 100 MG PO TABS       788.4
# 52333  TACHOSIL 4.8 X 4.8 CM EX PTCH      1571.2
# 52334        TISSEEL VH 10 ML EX KIT     2349.32
# 52335         TISSEEL VH 2 ML EX KIT     494.225
# 52336         TISSEEL VH 4 ML EX KIT       839.3
#
# 1     IP XR\nBlue Shield IP XR\nCigna IP XR\nHealth Net IP XR\nKaiser  \
# 2               Variable     Variable          Variable      Variable
# 3               Variable     Variable          Variable      Variable
# 4               Variable     Variable          Variable      Variable
# 5               Variable     Variable          Variable      Variable
# 6               Variable     Variable          Variable      Variable
# ...                  ...          ...               ...           ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# 1       IP XR\nUnited       Min       Max
# 2      1129072.495194  Variable  Variable
# 3       545434.368297  Variable  Variable
# 4       709253.482476  Variable  Variable
# 5        439008.36654  Variable  Variable
# 6       680656.478244  Variable  Variable
# ...               ...       ...       ...
# 52332
# 52333
# 52334
# 52335
# 52336
#
# [52335 rows x 16 columns]

# %%
ucla=new_ucla.reset_index(drop=True)

# %%
ucla
# Out:
# 1                                            Description      Code \nType  \
# 0      Heart transplant or implant of heart assist sy...              DRG
# 1      Heart transplant or implant of heart assist sy...              DRG
# 2      ECMO or trach w MV >96 hrs or PDX exc face, mo...              DRG
# 3      Trach w MV >96 hrs or PDX exc face, mouth & ne...              DRG
# 4                                       Liver transplant              DRG
# ...                                                  ...              ...
# 52330                                         SM, RR, NP  Pharmaceuticals
# 52331                                         SM, RR, NP  Pharmaceuticals
# 52332                                         SM, RR, NP  Pharmaceuticals
# 52333                                         SM, RR, NP  Pharmaceuticals
# 52334                                         SM, RR, NP  Pharmaceuticals
#
# 1         CPT/HCPCS \nDRG Code Code\nCDM/ERX/SUP    NDC Revenue\nCode  \
# 0      MS-DRG V37 (FY2020) 001                       NA
# 1      MS-DRG V37 (FY2020) 002                       NA
# 2      MS-DRG V37 (FY2020) 003                       NA
# 3      MS-DRG V37 (FY2020) 004                       NA
# 4      MS-DRG V37 (FY2020) 005                       NA
# ...                        ...               ...    ...           ...
# 52330                               50242-063-01  C9399    2500003636
# 52331                               0944-8702-02  C9399    2500003636
# 52332                               0338-4212-10  C9399    2500003636
# 52333                               0338-4210-02  C9399    2500003636
# 52334                               0338-4211-04  C9399    2500003636
#
# 1                           Quantity IP XR Aetna IP XR Anthem  \
# 0                                       Variable     Variable
# 1                                       Variable     Variable
# 2                                       Variable     Variable
# 3                                       Variable     Variable
# 4                                       Variable     Variable
# ...                              ...         ...          ...
# 52330   ERLOTINIB HCL 100 MG PO TABS       788.4
# 52331  TACHOSIL 4.8 X 4.8 CM EX PTCH      1571.2
# 52332        TISSEEL VH 10 ML EX KIT     2349.32
# 52333         TISSEEL VH 2 ML EX KIT     494.225
# 52334         TISSEEL VH 4 ML EX KIT       839.3
#
# 1     IP XR\nBlue Shield IP XR\nCigna IP XR\nHealth Net IP XR\nKaiser  \
# 0               Variable     Variable          Variable      Variable
# 1               Variable     Variable          Variable      Variable
# 2               Variable     Variable          Variable      Variable
# 3               Variable     Variable          Variable      Variable
# 4               Variable     Variable          Variable      Variable
# ...                  ...          ...               ...           ...
# 52330
# 52331
# 52332
# 52333
# 52334
#
# 1       IP XR\nUnited       Min       Max
# 0      1129072.495194  Variable  Variable
# 1       545434.368297  Variable  Variable
# 2       709253.482476  Variable  Variable
# 3        439008.36654  Variable  Variable
# 4       680656.478244  Variable  Variable
# ...               ...       ...       ...
# 52330
# 52331
# 52332
# 52333
# 52334
#
# [52335 rows x 16 columns]

# %%
ucla.to_csv('ucla.csv',index=False)

# %%
# inpatient_df=ucla['Code \nType'].str.contains('DRG')

# %%
# inpatient_df
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 52330    False
# 52331    False
# 52332    False
# 52333    False
# 52334    False
# Name: Code \nType, Length: 52335, dtype: bool
