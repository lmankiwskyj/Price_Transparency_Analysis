# %%
import pandas as pd
import os

# %%
data = pd.read_json('237309937_Barnes-JewishHospital_standardcharges.json', lines=True)
data
# Out:
#       file_create_date                                run_id  \
# 0           2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 1           2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 2           2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 3           2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 4           2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# ...                ...                                   ...
# 33553       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 33554       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 33555       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 33556       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 33557       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
#
#                          name      tax_id code code type  \
# 0      Barnes-Jewish Hospital  23-7309937  110   revCode
# 1      Barnes-Jewish Hospital  23-7309937  117   revCode
# 2      Barnes-Jewish Hospital  23-7309937  117   revCode
# 3      Barnes-Jewish Hospital  23-7309937  122   revCode
# 4      Barnes-Jewish Hospital  23-7309937  122   revCode
# ...                       ...         ...  ...       ...
# 33553  Barnes-Jewish Hospital  23-7309937  278   revCode
# 33554  Barnes-Jewish Hospital  23-7309937  278   revCode
# 33555  Barnes-Jewish Hospital  23-7309937  278   revCode
# 33556  Barnes-Jewish Hospital  23-7309937  278   revCode
# 33557  Barnes-Jewish Hospital  23-7309937  278   revCode
#
#                                         code description       payer  \
# 0                                  ROOM PRIVATE AHF TELE  All Payers
# 1                                       ROOM PRIVATE ONC  All Payers
# 2                                  ROOM PRIVATE ONC TELE  All Payers
# 3                                     ROOM SEMIPRVATE OB  All Payers
# 4                                ROOM SEMIPRVATE OB TELE  All Payers
# ...                                                  ...         ...
# 33553  PLATE 72468104 BONE EVOS STANDARD L56 MM RADIA...  All Payers
# 33554             PLATE MPP2200R LAPIDUS DUAL MODE RIGHT  All Payers
# 33555  PLATE 02.110.013S BONE STAINLESS STEEL 13 HOLE...  All Payers
# 33556  HEAD 802202801 -3.5MM UNIVERSAL 28MM FEMORAL H...  All Payers
# 33557  PLATE 78-91001 BONE FACIAL ID 1 RECONSTRUCTION...  All Payers
#
#       patient_class  gross charge  de-identified minimum negotiated charge  \
# 0                 O        4700.0                                      NaN
# 1                 O        4900.0                                      NaN
# 2                 O        6100.0                                      NaN
# 3                 O        1900.0                                      NaN
# 4                 O        2400.0                                      NaN
# ...             ...           ...                                      ...
# 33553             O        1761.0                                      NaN
# 33554             O        5583.0                                      NaN
# 33555             O        5085.0                                      NaN
# 33556             O        1544.0                                      NaN
# 33557             O       27073.0                                      NaN
#
#        payer-specific negotiated charge  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 33553                               NaN
# 33554                               NaN
# 33555                               NaN
# 33556                               NaN
# 33557                               NaN
#
#        de-identified maximum negotiated charge  discounted cash price  \
# 0                                          NaN                 2820.0
# 1                                          NaN                 2940.0
# 2                                          NaN                 3660.0
# 3                                          NaN                 1140.0
# 4                                          NaN                 1440.0
# ...                                        ...                    ...
# 33553                                      NaN                 1057.0
# 33554                                      NaN                 3350.0
# 33555                                      NaN                 3051.0
# 33556                                      NaN                  926.0
# 33557                                      NaN                16244.0
#
#       disclaimer
# 0
# 1
# 2
# 3
# 4
# ...          ...
# 33553
# 33554
# 33555
# 33556
# 33557
#
# [33558 rows x 15 columns]

# %%
pd.options.display.max_info_columns = 150
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33558 entries, 0 to 33557
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   file_create_date                         33558 non-null  object
#  1   run_id                                   33558 non-null  object
#  2   name                                     33558 non-null  object
#  3   tax_id                                   33558 non-null  object
#  4   code                                     33558 non-null  object
#  5   code type                                33558 non-null  object
#  6   code description                         33558 non-null  object
#  7   payer                                    33558 non-null  object
#  8   patient_class                            33558 non-null  object
#  9   gross charge                             33558 non-null  float64
#  10  de-identified minimum negotiated charge  14530 non-null  float64
#  11  payer-specific negotiated charge         14530 non-null  float64
#  12  de-identified maximum negotiated charge  14530 non-null  float64
#  13  discounted cash price                    33558 non-null  float64
#  14  disclaimer                               33558 non-null  object
# dtypes: float64(5), object(10)
# memory usage: 3.8+ MB

# %%
data.describe()
# Out:
#         gross charge  de-identified minimum negotiated charge  \
# count   33558.000000                             14530.000000
# mean     6177.478686                              2266.017758
# std     20955.809803                              7499.853770
# min         0.560000                                 0.650000
# 25%       166.000000                                14.250000
# 50%       613.000000                                60.170000
# 75%      3616.330000                               781.580000
# max    759974.570000                            229880.180000
#
#        payer-specific negotiated charge  \
# count                      14530.000000
# mean                        4427.392030
# std                        17861.576523
# min                            0.650000
# 25%                           37.430000
# 50%                          194.935000
# 75%                         2477.272500
# max                       823754.200000
#
#        de-identified maximum negotiated charge  discounted cash price
# count                             14530.000000           33558.000000
# mean                               7442.775017            3706.486603
# std                               29195.224152           12573.485394
# min                                   4.370000               0.000000
# 25%                                 119.047500              99.600000
# 50%                                 467.000000             368.000000
# 75%                                5498.590000            2169.800000
# max                              823754.200000          455984.740000

# %%
#Remove Rev Code from data set 
drop_rev_code = data[ (data['code type']) == 'revCode'].index

# drop these row indexes
# from dataFrame
data.drop(drop_rev_code, inplace = True)
  
data
# Out:
#       file_create_date                                run_id  \
# 204         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 205         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 206         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 207         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 208         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# ...                ...                                   ...
# 24224       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 24225       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 24226       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 24227       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 24228       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
#
#                          name      tax_id   code code type  \
# 204    Barnes-Jewish Hospital  23-7309937    001    ms-drg
# 205    Barnes-Jewish Hospital  23-7309937    003    ms-drg
# 206    Barnes-Jewish Hospital  23-7309937    003    ms-drg
# 207    Barnes-Jewish Hospital  23-7309937    003    ms-drg
# 208    Barnes-Jewish Hospital  23-7309937    004    ms-drg
# ...                       ...         ...    ...       ...
# 24224  Barnes-Jewish Hospital  23-7309937  99254       cpt
# 24225  Barnes-Jewish Hospital  23-7309937  99254       cpt
# 24226  Barnes-Jewish Hospital  23-7309937  99254       cpt
# 24227  Barnes-Jewish Hospital  23-7309937  99254       cpt
# 24228  Barnes-Jewish Hospital  23-7309937  99254       cpt
#
#                                         code description  \
# 204    heart transplant or implant of heart assist sy...
# 205    ecmo or tracheostomy with mv >96 hours or prin...
# 206    ecmo or tracheostomy with mv >96 hours or prin...
# 207    ecmo or tracheostomy with mv >96 hours or prin...
# 208    tracheostomy with mv >96 hours or principal di...
# ...                                                  ...
# 24224  PR INITL INPATIENT CONSULT NEW/ESTAB PT 80 MIN...
# 24225  PR INITL INPATIENT CONSULT NEW/ESTAB PT 80 MIN...
# 24226  PR INITL INPATIENT CONSULT NEW/ESTAB PT 80 MIN...
# 24227  PR INITL INPATIENT CONSULT NEW/ESTAB PT 80 MIN...
# 24228  PR INITL INPATIENT CONSULT NEW/ESTAB PT 80 MIN...
#
#                       payer patient_class  gross charge  \
# 204            TRNPLT OPTUM             I     759974.57
# 205       ACCESS CHOICE PPO             I     465368.33
# 206    BL CHOICE PRF PPO IL             I     465368.33
# 207      UHC COMMUNITY PLAN             I     465368.33
# 208       ACCESS CHOICE PPO             I     312805.34
# ...                     ...           ...           ...
# 24224     Access Choice PPO             I        336.00
# 24225           Aetna Local             I        336.00
# 24226         Anthem Access             I        336.00
# 24227                 Cigna             I        336.00
# 24228                   UHC             I        336.00
#
#        de-identified minimum negotiated charge  \
# 204                                   35033.40
# 205                                   61440.88
# 206                                   61440.88
# 207                                   61440.88
# 208                                   76386.64
# ...                                        ...
# 24224                                   198.56
# 24225                                   198.56
# 24226                                   198.56
# 24227                                   198.56
# 24228                                   198.56
#
#        payer-specific negotiated charge  \
# 204                           225903.73
# 205                           338303.47
# 206                           823754.20
# 207                            61440.88
# 208                           277191.11
# ...                                 ...
# 24224                            213.37
# 24225                            268.64
# 24226                            257.44
# 24227                            239.73
# 24228                            198.56
#
#        de-identified maximum negotiated charge  discounted cash price  \
# 204                                  369533.60              455984.74
# 205                                  823754.20              279221.00
# 206                                  823754.20              279221.00
# 207                                  823754.20              279221.00
# 208                                  277191.11              187683.20
# ...                                        ...                    ...
# 24224                                   298.74                 201.60
# 24225                                   298.74                 201.60
# 24226                                   298.74                 201.60
# 24227                                   298.74                 201.60
# 24228                                   298.74                 201.60
#
#       disclaimer
# 204
# 205
# 206
# 207
# 208
# ...          ...
# 24224
# 24225
# 24226
# 24227
# 24228
#
# [14530 rows x 15 columns]

# %%
#Remove cpt codes from data set 
drop_rev_code = data[ (data['code type']) == 'cpt'].index

# drop these row indexes
# from dataFrame
data.drop(drop_rev_code, inplace = True)
  
data
# Out:
#       file_create_date                                run_id  \
# 204         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 205         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 206         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 207         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 208         2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# ...                ...                                   ...
# 23734       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 23735       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 23736       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 23737       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
# 23738       2021-08-30  35e7299c-09c6-11ec-87c9-02000a000a0a
#
#                          name      tax_id code code type  \
# 204    Barnes-Jewish Hospital  23-7309937  001    ms-drg
# 205    Barnes-Jewish Hospital  23-7309937  003    ms-drg
# 206    Barnes-Jewish Hospital  23-7309937  003    ms-drg
# 207    Barnes-Jewish Hospital  23-7309937  003    ms-drg
# 208    Barnes-Jewish Hospital  23-7309937  004    ms-drg
# ...                       ...         ...  ...       ...
# 23734  Barnes-Jewish Hospital  23-7309937  982    ms-drg
# 23735  Barnes-Jewish Hospital  23-7309937  982    ms-drg
# 23736  Barnes-Jewish Hospital  23-7309937  982    ms-drg
# 23737  Barnes-Jewish Hospital  23-7309937  983    ms-drg
# 23738  Barnes-Jewish Hospital  23-7309937  987    ms-drg
#
#                                         code description  \
# 204    heart transplant or implant of heart assist sy...
# 205    ecmo or tracheostomy with mv >96 hours or prin...
# 206    ecmo or tracheostomy with mv >96 hours or prin...
# 207    ecmo or tracheostomy with mv >96 hours or prin...
# 208    tracheostomy with mv >96 hours or principal di...
# ...                                                  ...
# 23734  extensive o.r. procedures unrelated to princip...
# 23735  extensive o.r. procedures unrelated to princip...
# 23736  extensive o.r. procedures unrelated to princip...
# 23737  extensive o.r. procedures unrelated to princip...
# 23738  non-extensive o.r. procedures unrelated to pri...
#
#                       payer patient_class  gross charge  \
# 204            TRNPLT OPTUM             I     759974.57
# 205       ACCESS CHOICE PPO             I     465368.33
# 206    BL CHOICE PRF PPO IL             I     465368.33
# 207      UHC COMMUNITY PLAN             I     465368.33
# 208       ACCESS CHOICE PPO             I     312805.34
# ...                     ...           ...           ...
# 23734            ACCESS PPO             I      56819.16
# 23735                   UHC             I      56819.16
# 23736          UHC MEDICARE             I      56819.16
# 23737            ACCESS PPO             I      40214.57
# 23738          UHC MEDICARE             I      73817.40
#
#        de-identified minimum negotiated charge  \
# 204                                   35033.40
# 205                                   61440.88
# 206                                   61440.88
# 207                                   61440.88
# 208                                   76386.64
# ...                                        ...
# 23734                                 12816.00
# 23735                                 12816.00
# 23736                                 12816.00
# 23737                                 31154.50
# 23738                                 19819.52
#
#        payer-specific negotiated charge  \
# 204                           225903.73
# 205                           338303.47
# 206                           823754.20
# 207                            61440.88
# 208                           277191.11
# ...                                 ...
# 23734                          48547.19
# 23735                          12816.00
# 23736                          19367.35
# 23737                          31154.50
# 23738                          25977.36
#
#        de-identified maximum negotiated charge  discounted cash price  \
# 204                                  369533.60              455984.74
# 205                                  823754.20              279221.00
# 206                                  823754.20              279221.00
# 207                                  823754.20              279221.00
# 208                                  277191.11              187683.20
# ...                                        ...                    ...
# 23734                                 48547.19               34091.50
# 23735                                 48547.19               34091.50
# 23736                                 48547.19               34091.50
# 23737                                 31154.50               24128.74
# 23738                                 65096.93               44290.44
#
#       disclaimer
# 204
# 205
# 206
# 207
# 208
# ...          ...
# 23734
# 23735
# 23736
# 23737
# 23738
#
# [1409 rows x 15 columns]

# %%
pd.options.display.max_info_columns = 150
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1409 entries, 204 to 23738
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   file_create_date                         1409 non-null   object
#  1   run_id                                   1409 non-null   object
#  2   name                                     1409 non-null   object
#  3   tax_id                                   1409 non-null   object
#  4   code                                     1409 non-null   object
#  5   code type                                1409 non-null   object
#  6   code description                         1409 non-null   object
#  7   payer                                    1409 non-null   object
#  8   patient_class                            1409 non-null   object
#  9   gross charge                             1409 non-null   float64
#  10  de-identified minimum negotiated charge  1409 non-null   float64
#  11  payer-specific negotiated charge         1409 non-null   float64
#  12  de-identified maximum negotiated charge  1409 non-null   float64
#  13  discounted cash price                    1409 non-null   float64
#  14  disclaimer                               1409 non-null   object
# dtypes: float64(5), object(10)
# memory usage: 176.1+ KB

# %%
data.to_csv('C:/Users/kethr/Desktop/Class/Final Project/USNWR Hospital Charges/Barnes_Jewish_clean.csv')
